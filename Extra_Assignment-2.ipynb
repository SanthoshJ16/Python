# %%
# print 0 to 20 by using range
for num in range(0,20):
    print(num)

# %%
# print range 10 to 20
for num in range(10,20):
    print(num)

# %%
# Print number of items in the list by using 'len'
list=[10, 20, 14, 55, 43, 87, 76]
print(len(list))

# %%
# Split characters Artificial Intelligence
text="Artificial Intelligence"
for temp in text:
    print(temp)

# %%
# Tutorial on Get Name, Age, Profeesion Buy Inputs
name=input("Enter your Name:")
age=int(input("Enter your Age:"))
profession=input("Enter your Profession:")

print("Your Name :",name)
print("Your Age :",age)
print("Your Profession :",profession)

# %%
# Print this mixered datatype using Tuples
tup = (1, 'Welcome', 2, 'Hope')
print(tup)

# %%
# Print this mixered Tuples
tuple1=(0,1,2,3)
tuple2=("Python","Hope")
tuple3=(tuple1,tuple2)
print(tuple3)

# %%
# print Odd Numbers in the list
list=(20,10,16,19,25,1,276,188)
for num in list:
    if(num%2==1):
        print(num, "Is Odd")

# %%
# print Even numbers in the list
list1=(20,10,16,19,25,1,276,188)
for num1 in list1:
    if(num1%2==0):
        print(num1, "Is Even")
# Out:
# 20 Is Even
# 10 Is Even
# 16 Is Even
# 276 Is Even
# 188 Is Even
