# %%
from allFunction import Calculator,SubfieldsInAI,ElegiblityForMarriage,FindPercent,Triangle

# %%
Calculator.oddEven()
Calculator.calcBMI()
SubfieldsInAI.subfields()
ElegiblityForMarriage.eligible()
FindPercent.percentage(98,87,95,95,93)
Triangle.triangle(32,34,2,4,4) #Used Parameterized values
# Out:
# Enter the Number: 33
# Odd Number
# Enter the BMI Index 21
# Subfields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 Calculator.calcBMI()
#       3 SubfieldsInAI.subfields()
# ----> 4 ElegiblityForMarriage.eligible()
#       5 FindPercent.percentage(98,87,95,95,93)
#       6 Triangle.triangle(32,34,2,4,4) #Used Parameterized values
#
# NameError: name 'ElegiblityForMarriage' is not defined
