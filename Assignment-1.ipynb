# %%
# Tutorial on print
print("Welcome to Assignment-1")

# %%
# Tutorial on Addition of two Numbers
num1=10
num2=30
add=num1+num2
print("Sum of two Numbers is :",add)

# %%
# Tutorial on BMI used Float function
bmi=float(input("Enter the BMI Index"))
if(bmi<=18.5):
    print("Underweight")
elif(bmi<=24.9):
    print("Normal range")
elif(bmi<=33.9):
    print("Overweight")
else:
    print("Extremely Overweight")
# Out:
# Enter the BMI Index 33
# Overweight
