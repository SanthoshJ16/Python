# %%
# Tutorial on print
print("Welcome to Hope AI")

# %%
# Tutorial on Buy Input
institute=input("Institute Name?")
print("Enter your institute name? :",institute)

# %%
# Tutorial on Buy Inputs
name=input("Enter your Name:")
age=int(input("Enter your Age:"))
school_name=input("Enter your School Name:")
degree=input("Enter your Degree:")

print("Entered Name :",name)
print("Entered Age :",age)
print("Entered School Name :",school_name)
print("Entered Degree :",degree)

# %%
# Tutorial on Addition
a=43
b=34
add=a+b
print("Addition =",add)

# Tutorial on Subtraction
sub=a-b
print("Subtraction =",sub)

# Tutorial on Multiplication
num1=63
num2=97
print("Multiplication =",num1*num2)

# Tutorial on Division
c=76
d=31
print("Division =",float(c/d))

# Tutorial on Floor Division
print("Floor Division =",c//d)

# Tutorial on Modulo
print("Modulo =",c%d)

# Tutorial on Power 
e=4
f=4
print("Power using function =",pow(e,f)) # Used power function here
print("Power using formula =",e**f)
